# %% [markdown]
# # Actividad Guiada 3: Análisis Visual Exploratorio y Storytelling
#
# **Nombre del Estudiante:** [Juan Camilo Angel Torrente]
#
# ## Contexto
# Eres un Analista de Datos y tu misión es analizar un dataset de ventas globales para extraer insights clave a través de visualizaciones. Utilizarás Matplotlib, Seaborn y Plotly para contar la historia que esconden los datos.

# %% [markdown]
# ### Parte 0: Configuración Inicial
#
# **Tarea:** Importa las librerías necesarias (pandas, matplotlib.pyplot, seaborn, plotly.express) y carga el dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from io import StringIO

# --- Carga del Dataset ---
csv_data = '''ID_Pedido,Fecha,Region,Categoria,Unidades_Vendidas,Precio_Unitario,Ingresos_Totales,Pais
1,2023-04-13,Europa,Libros,8,29.99,239.92,Germany
2,2023-12-15,Norteamérica,Ropa,6,99.99,599.9399999999999,Canada
3,2023-09-28,Norteamérica,Electrónica,5,49.99,249.95000000000002,Canada
4,2023-04-17,Norteamérica,Ropa,9,99.99,899.91,Canada
5,2023-03-13,Norteamérica,Ropa,2,99.99,199.98,Canada
6,2023-07-08,Latinoamérica,Electrónica,5,199.99,999.95,Colombia
7,2023-01-21,Norteamérica,Hogar,6,29.99,179.94,Canada
8,2023-04-13,Asia,Electrónica,7,99.99,699.93,Japan
9,2023-05-02,Norteamérica,Hogar,5,499.99,2499.95,Canada
10,2023-08-03,Europa,Hogar,9,499.99,4499.91,Germany
11,2023-11-27,Asia,Electrónica,1,199.99,199.99,Japan
12,2023-03-29,Europa,Electrónica,7,29.99,209.92999999999998,Germany
13,2023-04-10,Europa,Hogar,7,29.99,209.92999999999998,Germany
14,2023-12-26,Europa,Ropa,4,499.99,1999.96,Germany
15,2023-06-01,Norteamérica,Electrónica,9,49.99,449.91,Canada
16,2023-05-11,Latinoamérica,Libros,5,199.99,999.95,Colombia
17,2023-05-30,Asia,Electrónica,4,199.99,799.96,Japan
18,2023-11-05,Latinoamérica,Hogar,7,499.99,3499.9300000000003,Colombia
19,2023-09-15,Norteamérica,Libros,4,499.99,1999.96,Canada
20,2023-12-10,Asia,Electrónica,3,49.99,149.97,Japan
21,2023-10-21,Latinoamérica,Electrónica,9,49.99,449.91,Colombia
22,2023-07-11,Norteamérica,Electrónica,8,29.99,239.92,Canada
23,2023-10-04,Norteamérica,Electrónica,1,199.99,199.99,Canada
24,2023-06-10,Asia,Electrónica,7,199.99,1399.93,Japan
25,2023-11-10,Europa,Hogar,9,499.99,4499.91,Germany
26,2023-01-22,Asia,Electrónica,8,29.99,239.92,Japan
27,2023-09-10,Norteamérica,Ropa,8,199.99,1599.92,Canada
28,2023-08-24,Asia,Libros,6,29.99,179.94,Japan
29,2023-12-11,Norteamérica,Hogar,4,29.99,119.96,Canada
30,2023-02-18,Norteamérica,Hogar,8,499.99,3999.92,Canada
31,2023-02-28,Norteamérica,Electrónica,3,29.99,89.97,Canada
32,2023-06-19,Asia,Hogar,9,49.99,449.91,Japan
33,2023-07-07,Europa,Ropa,2,49.99,99.98,Germany
34,2023-09-28,Europa,Ropa,2,99.99,199.98,Germany
35,2023-07-09,Norteamérica,Electrónica,7,499.99,3499.9300000000003,Canada
979,2023-06-22,Norteamérica,Electrónica,1,29.99,29.99,Canada
980,2023-10-27,Europa,Ropa,5,199.99,999.95,Germany
981,2023-05-13,Norteamérica,Electrónica,6,29.99,179.94,Canada
982,2023-11-22,Latinoamérica,Hogar,3,99.99,299.96999999999997,Colombia
983,2023-04-28,Europa,Electrónica,9,499.99,4499.91,Germany
984,2023-11-20,Asia,Ropa,6,99.99,599.9399999999999,Japan
985,2023-10-02,Norteamérica,Electrónica,4,29.99,119.96,Canada
986,2023-07-31,Asia,Electrónica,7,49.99,349.93,Japan
987,2023-08-13,Latinoamérica,Electrónica,8,499.99,3999.92,Colombia
988,2023-01-20,Europa,Ropa,9,99.99,899.91,Germany
989,2023-04-23,Europa,Ropa,6,199.99,1199.94,Germany
990,2023-05-20,Asia,Ropa,6,49.99,299.94,Japan
991,2023-02-16,Norteamérica,Ropa,8,99.99,799.92,Canada
992,2023-01-01,Europa,Ropa,5,199.99,999.95,Germany
993,2023-03-31,Norteamérica,Electrónica,3,29.99,89.97,Canada
994,2023-05-22,Norteamérica,Ropa,3,199.99,599.97,Canada
995,2023-11-16,Norteamérica,Libros,6,99.99,599.9399999999999,Canada
996,2023-02-07,Norteamérica,Ropa,2,99.99,199.98,Canada
997,2023-10-20,Norteamérica,Hogar,6,29.99,179.94,Canada
998,2023-05-19,Norteamérica,Electrónica,6,199.99,1199.94,Canada
999,2023-12-22,Latinoamérica,Hogar,8,199.99,1599.92,Colombia
1000,2023-11-29,Europa,Hogar,7,29.99,209.92999999999998,Germany
'''

df = pd.read_csv(StringIO(csv_data))
df['Fecha'] = pd.to_datetime(df['Fecha'])

print('Dataset cargado con éxito.')
df.head()
# Out:
# Dataset cargado con éxito.
#    ID_Pedido      Fecha        Region    Categoria  Unidades_Vendidas  \
# 0          1 2023-04-13        Europa       Libros                  8
# 1          2 2023-12-15  Norteamérica         Ropa                  6
# 2          3 2023-09-28  Norteamérica  Electrónica                  5
# 3          4 2023-04-17  Norteamérica         Ropa                  9
# 4          5 2023-03-13  Norteamérica         Ropa                  2
#
#    Precio_Unitario  Ingresos_Totales     Pais
# 0            29.99            239.92  Germany
# 1            99.99            599.94   Canada
# 2            49.99            249.95   Canada
# 3            99.99            899.91   Canada
# 4            99.99            199.98   Canada

# %% [markdown]
# ### Parte 1: Análisis Univariado (Entendiendo cada variable)
#
# **Punto 1:** Muestra un resumen estadístico de las columnas numéricas del DataFrame.

# %%
print("Revisión de datos inicial en busca de errores")
display(df.isnull().sum())# 1. Muestra los errores que se encuentren en el Dataset
resumen = df.describe()# 2. Asigna un Alias a df.describe()
print("Resumen estadístico de las columnas numéricas")
display(resumen)# 3. Muestra el resumen estadístico de las columnas númericas
# Out:
# Revisión de datos inicial en busca de errores
# ID_Pedido            0
# Fecha                0
# Region               0
# Categoria            0
# Unidades_Vendidas    0
# Precio_Unitario      0
# Ingresos_Totales     0
# Pais                 0
# dtype: int64
# Resumen estadístico de las columnas numéricas
#          ID_Pedido                       Fecha  Unidades_Vendidas  \
# count  1000.000000                        1000        1000.000000
# mean    500.500000  2023-07-01 13:22:04.800000           5.043000
# min       1.000000         2023-01-01 00:00:00           1.000000
# 25%     250.750000         2023-04-08 00:00:00           3.000000
# 50%     500.500000         2023-07-01 12:00:00           5.000000
# 75%     750.250000         2023-09-27 06:00:00           7.000000
# max    1000.000000         2023-12-31 00:00:00           9.000000
# std     288.819436                         NaN           2.583375
#
#        Precio_Unitario  Ingresos_Totales
# ...

# %% [markdown]
# **Punto 2:** Crea un **histograma con Seaborn** para visualizar la distribución de la columna `Ingresos_Totales`. Añade una línea de densidad (KDE).

# %%
plt.figure(figsize=(10,5))# 1. Definir el tamaño de la figura
sns.histplot(data=df, x="Ingresos_Totales", kde=True, bins=30, color="skyblue")# 2. Crear histograma con línea de densidad (kde=True)
plt.title("Distribución de Ingresos Totales", fontsize=14)# 3. Añadir título y etiquetas
plt.xlabel("Ingresos Totales", fontsize=12)
plt.ylabel("Frecuencia", fontsize=12)
plt.show()# 4. Mostrar el gráfico

# %% [markdown]
# **Punto 3:** Crea un **gráfico de conteo con Seaborn** para ver la cantidad de ventas por `Categoria`.

# %%
sns.set_style("whitegrid")# 1. Ajustar estilo de Seaborn para que sea más estético
plt.figure(figsize=(10,5))# 2. Definir tamaño del gráfico
sns.countplot(data=df, x="Categoria", palette="Set2")# 3. Crear gráfico de conteo por 'Categoria',cuenta cuántas filas hay por cada categoría.
plt.title("Cantidad de Ventas por Categoría", fontsize=14)# 4. Añadir título y etiquetas
plt.xlabel("Categoría", fontsize=12)
plt.ylabel("Cantidad de Ventas", fontsize=12)
plt.show()# 5. Mostrar el gráfico
# Out:
# /tmp/ipython-input-1310517369.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **Punto 4:** Crea un **gráfico de pastel con Matplotlib** para mostrar la proporción de ventas por `Region`. Asegúrate de que se vean los porcentajes.

# %%
ventas_por_region = df["Region"].value_counts()# 1. Agrupar los datos por Región y contar las ventas
plt.figure(figsize=(8,8))# 2. Definir el tamaño del gráfico

# 3. Crear gráfico de pastel con porcentajes
plt.pie(
    ventas_por_region,                      # valores
    labels=ventas_por_region.index,         # nombres de las regiones
    autopct='%1.1f%%',                      # mostrar porcentajes con 1 decimal
    startangle=90,                          # rotación inicial para que empiece "derecho"
)
plt.title("Proporción de Ventas por Región", fontsize=16)# 4. Añadir título
plt.axis("equal")# 5. Centrar la gráfica
plt.show()# 6. Mostrar gráfico

# %% [markdown]
# ### Parte 2: Análisis Bivariado (Encontrando relaciones)
#
# **Punto 5:** Crea un **gráfico de dispersión (scatter plot) con Seaborn** para investigar la relación entre `Precio_Unitario` y `Unidades_Vendidas`.

# %%
plt.figure(figsize=(10,5))# 1. Definir el tamaño de la figura

# 2. Crear gráfico de dispersión
sns.scatterplot(
    data=df,
    x="Precio_Unitario",
    y="Unidades_Vendidas",
    color="royalblue",
    alpha=0.6,          # transparencia para ver mejor si hay puntos solapados
    s=60                # tamaño de los puntos
)

plt.title("Relación entre Precio Unitario y Unidades Vendidas", fontsize=16)# 3. Añadir título y etiquetas
plt.xlabel("Precio Unitario", fontsize=12)
plt.ylabel("Unidades Vendidas", fontsize=12)
plt.show()# 4. Mostrar gráfico

# %% [markdown]
# **Punto 6:** Crea un **gráfico de barras con Seaborn** que muestre el total de `Ingresos_Totales` por cada `Region`.

# %%
plt.figure(figsize=(10,5))# 1. Definir tamaño de la figura

# 2. Crear gráfico de barras con agregación por suma
sns.barplot(
    data=df,
    x="Region",
    y="Ingresos_Totales",
    estimator=sum,# suma los ingresos por cada región
    hue="Region",
    palette="Set1",
)

plt.title("Total de Ingresos por Región", fontsize=14)# 3. Añadir título y etiquetas
plt.xlabel("Región", fontsize=12)
plt.ylabel("Ingresos Totales", fontsize=12)
plt.show()# 4. Mostrar gráfico

# %% [markdown]
# **Punto 7:** Crea un **gráfico de caja (box plot) con Seaborn** para comparar la distribución de `Ingresos_Totales` entre las diferentes `Categorias`.

# %%
plt.figure(figsize=(8,5))# 1. Definir tamaño del gráfico

# 2. Crear boxplot comparando Ingresos_Totales por Categoria
sns.boxplot(
    data=df,
    x="Categoria",
    y="Ingresos_Totales",
    hue="Categoria",
    palette="Set3"
)

plt.title("Distribución de Ingresos Totales por Categoría", fontsize=14)# 3. Añadir título y etiquetas
plt.xlabel("Categoría", fontsize=12)
plt.ylabel("Ingresos Totales", fontsize=12)
plt.show()# 4. Mostrar gráfico

# %% [markdown]
# **Punto 8:** Crea un **mapa de calor (heatmap) con Seaborn** para visualizar la matriz de correlación de las variables numéricas.

# %%
corr = df.corr(numeric_only=True)# 1. Calcular la matriz de correlación de las variables numéricas
plt.figure(figsize=(8,6))# 2. Definir el tamaño de la figura

# 3. Crear heatmap con anotaciones
sns.heatmap(
    corr,
    annot=True,        # mostrar valores en cada celda
    fmt=".2f",         # formato de los números (2 decimales)
    cmap="coolwarm",   # paleta de colores rojo-azul
    center=0,          # centrar en 0 para distinguir correlaciones negativas
    linewidths=0.5     # líneas entre celdas
)

plt.title("Matriz de Correlación (variables numéricas)", fontsize=14)# 4. Añadir título
plt.show()# 5. Mostrar gráfico

# %% [markdown]
# ### Parte 3: Visualización Interactiva con Plotly
#
# **Punto 9:** Crea un **histograma interactivo con Plotly** de los `Ingresos_Totales`, separando por color según la `Region`.

# %%
# 1. Crear histograma interactivo
fig = px.histogram(
    df,
    x="Ingresos_Totales",     # variable en el eje X
    color="Region",           # separar por colores según región
    nbins=30,                 # número de barras del histograma
    barmode="overlay",        # superponer barras
    opacity=0.7,              # transparencia para ver solapamientos
    title="Distribución de Ingresos Totales por Región"
)

fig.show()# 2. Mostrar gráfico
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Punto 10:** Crea un **gráfico de dispersión interactivo con Plotly** que relacione `Precio_Unitario` con `Ingresos_Totales`. Usa el color para diferenciar por `Categoria` y el tamaño de los puntos para representar las `Unidades_Vendidas`.

# %%
# 1. Crear scatter plot interactivo
fig = px.scatter(
    df,
    x="Precio_Unitario",
    y="Ingresos_Totales",
    color="Categoria",              # colores por categoría
    size="Unidades_Vendidas",       # tamaño de los puntos
    opacity=0.7,
    hover_data=["Region"],          # info extra al pasar el mouse
    title="Relación entre Precio Unitario e Ingresos Totales"
)

fig.show()# 2. Mostrar gráfico
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Como en el anterior se sobreponen y no es posible mirarlos bien ni clasificando por categoría, se procede a buscar código alternativo para ver los cuatro simultaneamente
fig = px.scatter(
    df,
    x="Precio_Unitario",
    y="Ingresos_Totales",
    size="Unidades_Vendidas",
    color="Categoria",
    facet_col="Categoria",   #  Se añadepara dividir un gráfico en varios subgráficos (subplots) en columnas
    hover_data=["Region"],
    opacity=0.7,
    title="Relación entre Precio Unitario e Ingresos Totales por Categoría"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# :**Punto 11:** Crea un **gráfico de líneas interactivo con Plotly** que muestre la evolución de los `Ingresos_Totales` a lo largo del tiempo (`Fecha`).

# %%
df["Fecha"] = pd.to_datetime(df["Fecha"])# 1. Asegurarse de que la columna Fecha sea tipo datetime

# 2. Crear gráfico de líneas
fig = px.line(
    df,
    x="Fecha",
    y="Ingresos_Totales",
    title="Evolución de Ingresos Totales a lo largo del tiempo",
    markers=True  # añade puntos sobre la línea
)

fig.show()# 3. Mostrar gráfico
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Punto 12:** Crea un **mapa coroplético (choropleth) interactivo con Plotly** que muestre los `Ingresos_Totales` por `Pais`. Nota: Necesitarás agrupar los datos primero.

# %%
df_pais = df.groupby("Pais", as_index=False)["Ingresos_Totales"].sum()# 1. Agrupar los ingresos por país

# 2. Crear el mapa coroplético
fig = px.choropleth(
    df_pais,
    locations="Pais",                # columna con el nombre de los países
    locationmode="country names",    # usar nombres de países
    color="Ingresos_Totales",        # variable que define la intensidad de color
    color_continuous_scale="Blues",  # escala de color
    title="Ingresos Totales por País"
)

fig.show()# 3. Mostrar el mapa interactivo
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Parte 4: Storytelling y Personalización
#
# **Punto 13:** Usando **Matplotlib**, crea una figura que contenga dos subgráficos (subplots):
# 1. Un gráfico de barras con los ingresos totales por `Region`.
# 2. Un gráfico de barras con los ingresos totales por `Categoria`.
# Añade un título general a la figura.

# %%
ingresos_region = df.groupby("Region")["Ingresos_Totales"].sum()# 1. Agrupar datos
ingresos_categoria = df.groupby("Categoria")["Ingresos_Totales"].sum()
fig, axes = plt.subplots(1, 2, figsize=(12,5))# 2. Crear figura con subplots (1 fila, 2 columnas)

# 3. Gráfico de barras por Región
axes[0].bar(ingresos_region.index, ingresos_region.values, color="skyblue")
axes[0].set_title("Ingresos Totales por Región")
axes[0].set_xlabel("Región")
axes[0].set_ylabel("Ingresos Totales")
axes[0].tick_params(axis="x", rotation=45)

# 4. Gráfico de barras por Categoría
axes[1].bar(ingresos_categoria.index, ingresos_categoria.values, color="lightgreen")
axes[1].set_title("Ingresos Totales por Categoría")
axes[1].set_xlabel("Categoría")
axes[1].tick_params(axis="x", rotation=45)

fig.suptitle("Comparación de Ingresos por Región y Categoría", fontsize=16)# 5. Título general de la figura
plt.tight_layout()# 6. Ajustar márgenes
plt.show()# 7. Mostrar gráfico

# %% [markdown]
# **Punto 14:** Elige uno de tus gráficos de Seaborn o Matplotlib y personalízalo. Cambia los colores, añade títulos a los ejes X e Y, y un título principal claro y descriptivo.

# %%
ingresos_region = df.groupby("Region")["Ingresos_Totales"].sum()# 1. Agrupar datos
ingresos_categoria = df.groupby("Categoria")["Ingresos_Totales"].sum()
fig, axes = plt.subplots(1, 2, figsize=(12,8))# 2. Crear figura con subplots (1 fila, 2 columnas)
colores = ["red", "blue", "green", "orange"] # 3. Se agregan colores a cada barra
axes[0].bar(ingresos_region.index, ingresos_region.values, color=colores)# 4. Gráfico de barras por Región
axes[0].set_title("Ingresos Totales por Región")
axes[0].set_xlabel("Región", fontsize=18)
axes[0].set_ylabel("Ingresos Totales", fontsize=18)
axes[0].tick_params(axis="x", rotation=45)
axes[1].bar(ingresos_categoria.index, ingresos_categoria.values, color="brown")# 5. Gráfico de barras por Categoría
axes[1].set_title("Ingresos Totales por Categoría")
axes[1].set_xlabel("Categoría", fontsize=18)
axes[1].tick_params(axis="x", rotation=45)
fig.suptitle("Comparación de Ingresos por Región y Categoría", fontsize=20)# 6. Título general de la figura
plt.tight_layout()# 7. Ajustar márgenes y mostrar
plt.show() # 8. Mostrar gráfico

# %% [markdown]
# **Punto 15: Conclusión y Storytelling**
#
# Basándote en todas las visualizaciones que has creado, escribe en esta celda de Markdown un resumen con tus **tres principales hallazgos o insights** sobre las ventas de la empresa. ¿Qué le recomendarías al equipo de estrategia?
#
# **RESPUESTA**
#
# El análisis comprensivo de las visualizaciones de ventas revela un panorama empresarial con **oportunidades de crecimiento significativas** que requieren atencion inmediata, los datos muestran una empresa con potencial no aprovechado en mercados clave.
#
# Se hallan estos **Insights**:
#
# -Dominancia Norteamericana, genera el 39.5% de las ventas y los mayores ingresos, es el mercado más rentable. Sin embargo, se halla que Latinoamerica representa solo un 10% de las ventas a pesar de ser un mercado geográficamente próximo y culturalmente afín.
#
# -Inconsistencia entre volumen y rentabilidad regional, Europa representa el 30,4% de las ventas en volumen, pero genera ingresos significativamente menores que Norteamerica, por lo que se piensa que existe alguna brecha significativa de valor en la estructura de precios por región, no se está maximizando el valor de las transacciones.
#
# -Eléctrónicos, el gigante más rentable y el segmento desatendido (libros), la categoría electrónicos domina tanto en volumen como en ingresos, por lo que es el  producto estrella. Sin embargo, hay un constraste, una diferencia y es que libros muestra el menor volumen de ventas, tal vez el segmento de libros podría beneficiarse de estrategias de marketing más focalizadas.
#
# **RECOMENDACIONES**
#
# 1- Expansión agresiva en Latinoamerica, implementar estrategias de penetración de mercado, establecer alianzas locales y tener como meta incrementar su participación del 10% por lo menos al 20%.
#
# 2-Optimización por región, se sugiere realizar analisis de precios competitivos en Europa y Asia, implementar estrategias de mercado distintas para atraer ventas, como meta es aumentar los ingresos por transacción en estos mercados por lo menos un 10%
#
# 3-Revitalización de la categoría libros, para aumentar el volumen de ventas e ingresos, se sugiere desarrollas segmentación premium (ediciones especiales, libros ténicos), así mismo, explorar alianzas con instituciones educativas.
#
# 4-Electrónicos, se debe fortalecer el liderazgo en el sector eléctrico, aprovechando que es el punto fuerte de la empresa, por lo que se sugiere desarrollar programas de fidelización, expandir productos complementarios, se espera que así se mantenga la dominancia.
#
# **REFLEXIONES**
#
# Sí se implementan estas recomendaciones de forma adecuada, se espera un crecimiento potencial de ingresos, así mismo, sí se aumenta la presencia en latinoamerica, europa y asia se espera tener menor dependencia de norteamerica.
